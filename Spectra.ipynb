# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:44071")
client
# Out:
# <Client: 'tcp://127.0.0.1:44071' processes=6 threads=6, memory=17.58 GiB>

# %%
client.restart()
# Out:
# 2022-07-19 17:00:40,517 - distributed.client - ERROR - Restart timed out after 60.00 seconds
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File /mnt/meom/workdir/uchidat/miniconda3/envs/pyqg/lib/python3.9/site-packages/distributed/comm/tcp.py:229, in TCP.read(self, deserializers)
#     228 try:
# --> 229     frames_nbytes = await stream.read_bytes(fmt_size)
#     230     (frames_nbytes,) = struct.unpack(fmt, frames_nbytes)
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File /mnt/meom/workdir/uchidat/miniconda3/envs/pyqg/lib/python3.9/asyncio/tasks.py:490, in wait_for(fut, timeout, loop)
#     489 try:
# --> 490     return fut.result()
#     491 except exceptions.CancelledError as exc:
#
# CancelledError:
#
# ...

# %%
import numpy as np
import xarray as xr
import xrft
import xwavelet
import os.path as op
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ddir = '/mnt/meom/workdir/uchidat/pyqg-runs/'

# %%
N = 512
ds = xr.open_zarr(op.join(ddir,'Two-layer-QG/N%04d/rd=100km_outputs.zarr' % N)
                 )
ds = ds.isel(time=list(range(0,len(ds.time),4)),lev=0)
ds

# %%
ub = ds.u.mean('time').compute().chunk({'y':128,'x':128})
vb = ds.v.mean('time').compute().chunk({'y':128,'x':128})
qb = ds.q.mean('time').compute().chunk({'y':128,'x':128})

# %%
dsave = ub.to_dataset(name='u')
dsave['v'] = vb
dsave['q'] = qb
dsave.to_zarr(op.join(ddir,'Lev0_mean_UVQ.zarr'), mode='w')

# %%
# up = (ds.u - ub).reset_coords(drop=True)
# vp = (ds.v - vb).reset_coords(drop=True)
up = (ds.u).reset_coords(drop=True)
vp = (ds.v).reset_coords(drop=True)

L = 1000e3
rd = 100e3
xo = rd
dx = L/N

up

# %%
ss = xr.DataArray(np.linspace(2*dx,5*xo,50)/xo, dims=['scale'], 
                  coords={'scale':np.linspace(2*dx,5*xo,50)/xo}
                 )   
iso_psUw = xwavelet.wvlt_power_spectrum(
                    up, ss, dim=["y", "x"], xo=xo
           ).mean('time').compute()
iso_psVw = xwavelet.wvlt_power_spectrum(
                    vp, ss, dim=["y", "x"], xo=xo
           ).mean('time').compute()

# %%
dsave = iso_psUw.to_dataset(name='U')
dsave['V'] = iso_psVw
dsave.to_zarr(op.join(ddir,'Wavelet-KE-spec.zarr'), mode='w')
print(dsave)
dsave.close()

# %%
iso_psUf = xrft.isotropic_power_spectrum(
                    up.chunk({'y':-1,'x':-1}), 
                    dim=["y", "x"], 
                    # window='hann', 
                    # window_correction=True, 
                    true_amplitude=True, truncate=True
           ).mean('time').compute()
iso_psVf = xrft.isotropic_power_spectrum(
                    vp.chunk({'y':-1,'x':-1}), 
                    dim=["y", "x"], 
                    # window='hann', 
                    # window_correction=True, 
                    true_amplitude=True, truncate=True
           ).mean('time').compute()

ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
                   coords={'scale':iso_psUf.freq_r.data**-1/xo}
                  )
iso_psUwf = xwavelet.wvlt_power_spectrum(
                    up, ssf, dim=["y", "x"], xo=xo
            ).mean('time').compute()
iso_psVwf = xwavelet.wvlt_power_spectrum(
                    vp, ssf, dim=["y", "x"], xo=xo
            ).mean('time').compute()

# %%
dsave = iso_psUf.to_dataset(name='U')
dsave['V'] = iso_psVf
dsave.to_zarr(op.join(ddir,'Fourier-KE-spec.zarr'), mode='w')
print(dsave)
dsave.close()

# %%
dsave = iso_psUwf.to_dataset(name='U')
dsave['V'] = iso_psVwf
dsave.to_zarr(op.join(ddir,'Wavelet-KE-spec_FourierK.zarr'), mode='w')
print(dsave)
dsave.close()

# %%
dsw  = xr.open_zarr(op.join(ddir,'Wavelet-KE-spec.zarr'))
dsf  = xr.open_zarr(op.join(ddir,'Fourier-KE-spec.zarr'))
dswf = xr.open_zarr(op.join(ddir,'Wavelet-KE-spec_FourierK.zarr'))
dsw

# %%
w3 = (.5*(iso_psUw + iso_psVw).mean(['angle']) / ((iso_psUw.scale)**-1)**-3)
w53 = (.5*(iso_psUw + iso_psVw).mean(['angle']) / ((iso_psUw.scale)**-1)**(-5/3))
f3 = (.5*(iso_psUf + iso_psVf) / (iso_psUf.freq_r)**-3)
f53 = (.5*(iso_psUf + iso_psVf) / (iso_psUf.freq_r)**(-5/3))

# %%
fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
fig.set_tight_layout(True)
ax2 = ax1.twiny()
ax4 = ax3.twiny()

ax1.plot((iso_psUw.scale)**-1*1e3, 
         .5*(iso_psUw + iso_psVw).sum(['angle'])*np.diff(iso_psUw.angle)[0]*2,
         'k:', lw=2, label=r"Wavelet")
ax1.plot((iso_psUwf.scale)**-1*1e3, 
         .5*(iso_psUwf + iso_psVwf).sum(['angle'])*np.diff(iso_psUwf.angle)[0]*2,
         'k', label=r"Wavelet ($s_0 = k_F^{-1}$)")
ax1.plot((iso_psUf.freq_r)*1e3, 
         .5*(iso_psUf + iso_psVf).isel(lev=0)*2*np.pi,
         'r', lw=2, label=r"Fourier")
ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*4e-1, 
         ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(5/3)*4e-1, 
         ls='-.', c='grey', alpha=.8, label=r"$k^{-5/3}$")
            
ax3.plot((iso_psUw.scale)**-1*1e3, w3/w3.mean(),
         'k', lw=2, label=r"$\alpha=-3$")
ax3.plot((iso_psUw.scale)**-1*1e3, w53/w53.mean(),
         'k--', lw=2, label=r"$\alpha=-5/3$")
ax3.plot((iso_psUf.freq_r)*1e3, f3/f3.mean(),
         'r', lw=2, label=r"")
ax3.plot((iso_psUf.freq_r)*1e3, f53/f53.mean(),
         'r--', lw=2, label=r"")

ax1.set_xscale('log')
ax1.set_yscale('log')
ax3.set_xscale('log')

ax2.set_xscale('log')
ax2.set_yscale('log')
ax4.set_xscale('log')

ax1.set_xlim([1e-3,5e-1])
ax2.set_xlim([1e-3,5e-1])
ax3.set_xlim([1e-3,5e-1])
ax4.set_xlim([1e-3,5e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax4.set_xticks([1e-3,1e-2,1e-1])
ax4.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$E_K$ [(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
ax3.set_xlabel(r"[cpkm]", fontsize=13)
ax4.set_xlabel(r"[km]", fontsize=13)
ax3.set_ylabel(r"$E_K~/~k^{\alpha}$", fontsize=13)
if reg == 0:
    ax1.legend(loc='lower left', fontsize=12)
    ax3.legend(loc='upper right', fontsize=12)
ax3.grid(True)
plt.savefig(op.join(ddir,'Figs/WvsF_QG-lev0_KE-spec.pdf'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       3 ax2 = ax1.twiny()
#       4 ax4 = ax3.twiny()
# ----> 5 ax1.plot((iso_psUw.scale)**-1*1e3,
#       6          .5*(iso_psUw + iso_psVw).isel(lev=0).mean(['time']).sum(['angle'])*np.diff(iso_psUw.angle)[0]*2,
#       7          'k:', lw=2, label=r"Wavelet")
#       8 ax1.plot((iso_psUwf.scale)**-1*1e3,
#       9          .5*(iso_psUwf + iso_psVwf).isel(lev=0).mean(['time']).sum(['angle'])*np.diff(iso_psUwf.angle)[0]*2,
#      10          'k', label=r"Wavelet ($s=k_F^{-1}$)")
#      11 ax1.plot((iso_psUf.freq_r)*1e3,
#      12          .5*(iso_psUf + iso_psVf).isel(lev=0).mean(['time'])*2*np.pi,
#      13          'r', lw=2, label=r"Fourier")
#
# ...

# %%
qp = (ds.q - qb).isel(lev=0)

# %%
iso_psQw = xwavelet.wvlt_power_spectrum(
                    qp, ss, dim=["y", "x"], xo=xo
           ).mean('time').compute()

# %%
iso_psQf = xrft.isotropic_power_spectrum(
                    qp.chunk({'y':-1,'x':-1}), 
                    dim=["y", "x"], 
                    # window='hann', 
                    # window_correction=True, 
                    true_amplitude=True, truncate=True
           ).mean('time').compute()

ssf = xr.DataArray(iso_psQf.freq_r.data**-1/xo, dims=['scale'], 
                   coords={'scale':iso_psQf.freq_r.data**-1/xo}
                  )
iso_psQwf = xwavelet.wvlt_power_spectrum(
                    qp, ssf, dim=["y", "x"], xo=xo
            ).mean('time').compute()

# %%
w1 = (.5*(iso_psQw).mean(['angle']) / ((iso_psQw.scale)**-1)**-1)
f1 = (.5*(iso_psQf).mean(['angle']) / ((iso_psQf.scale)**-1)**-1)

# %%
fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
fig.set_tight_layout(True)
ax2 = ax1.twiny()
ax4 = ax3.twiny()
ax1.plot((iso_psQw.scale)**-1*1e3, 
         .5*(iso_psQw).sum(['angle'])*np.diff(iso_psQw.angle)[0]*2,
         'k:', lw=2, label=r"Wavelet")
ax1.plot((iso_psUwf.scale)**-1*1e3, 
         .5*(iso_psQwf).sum(['angle'])*np.diff(iso_psQwf.angle)[0]*2,
         'k', label=r"Wavelet ($s_0 = k_F^{-1}$)")
ax1.plot((iso_psQf.freq_r)*1e3, 
         .5*(iso_psQf)*2*np.pi,
         'r', lw=2, label=r"Fourier")
ax1.plot((iso_psQw.scale)**-1*1e3, ((iso_psQw.scale/xo)**-1)**-1*4e-1, 
         ls='--', c='grey', alpha=.8, label=r"$k^{-1}$")
            
ax3.plot((iso_psQw.scale)**-1*1e3, w1/w1.mean(),
         'k', lw=2, label=r"$\alpha=-1$")
ax3.plot((iso_psQf.freq_r)*1e3, f1/f1.mean(),
         'r', lw=2, label=r"")

ax1.set_xscale('log')
ax1.set_yscale('log')
ax3.set_xscale('log')

ax2.set_xscale('log')
ax2.set_yscale('log')
ax4.set_xscale('log')

ax1.set_xlim([1e-3,5e-1])
ax2.set_xlim([1e-3,5e-1])
ax3.set_xlim([1e-3,5e-1])
ax4.set_xlim([1e-3,5e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax4.set_xticks([1e-3,1e-2,1e-1])
ax4.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$Z_K$ [(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
ax3.set_xlabel(r"[cpkm]", fontsize=13)
ax4.set_xlabel(r"[km]", fontsize=13)
ax3.set_ylabel(r"$Z_K~/~k^{\alpha}$", fontsize=13)
if reg == 0:
    ax1.legend(loc='lower left', fontsize=12)
    ax3.legend(loc='upper right', fontsize=12)
ax3.grid(True)
plt.savefig(op.join(ddir,'Figs/WvsF_QG-lev0_Ens-spec.pdf'))
